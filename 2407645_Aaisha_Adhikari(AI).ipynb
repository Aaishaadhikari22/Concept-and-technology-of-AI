# %% [markdown]
# # **3 Tasks - To - Do:**

# %% [markdown]
# 3.1 Problem - 1: Getting Started with Data Exploration - Some Warm up
# Exercises:
# • Dataset Overview:
# 1. Load the dataset and display the first 10 rows.
# 2. Identify the number of rows and columns in the dataset.
# 3. List all the columns and their data types.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/WHR-2024-5CS037.csv')

# %%
# Display first 10 rows
print("First 10 rows of the dataset:")
df.head(10)
# Out:
# First 10 rows of the dataset:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
# Display how many rows and columns are present
print(f"\nNumber of rows: {df.shape[0]}, Number of columns: {df.shape[1]}")
# Out:
# Number of rows: 143, Number of columns: 9

# %%
#Display data types
print("Column names and data types:")
df.dtypes
# Out:
# Column names and data types:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# • Basic Statistics:
# 1. Calculate the mean, median, and standard deviation for the Score column.
# 2. Identify the country with the highest and lowest happiness scores.

# %%
# Mean, median, and standard deviation of the Score column
mean_score = df['score'].mean()
median_score = df['score'].median()
std_score = df['score'].std()

print(f"\nMean of Score: {mean_score:.2f}")
print(f"Median of Score: {median_score:.2f}")
print(f"Standard Deviation of Score: {std_score:.2f}")
# Out:
# Mean of Score: 5.53
# Median of Score: 5.79
# Standard Deviation of Score: 1.17

# %%
# Countries with highest and lowest scores
max_score_country = df.loc[df['score'].idxmax(), 'Country name']
min_score_country = df.loc[df['score'].idxmin(), 'Country name']

print(f"\nCountry with highest Score: {max_score_country}")
print(f"Country with lowest Score: {min_score_country}")
# Out:
# Country with highest Score: Finland
# Country with lowest Score: Afghanistan

# %% [markdown]
# • Missing Values:
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
# Check for missing values
print("\nMissing Values in Each Column:")
df.isnull().sum()
# Out:
# Missing Values in Each Column:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
# Filter countries with Score greater than 7.5
high_score_df = df[df['score'] > 7.5]
print("\nCountries with Score > 7.5:")
high_score_df[['Country name', 'score']]
# Out:
# Countries with Score > 7.5:
#   Country name  score
# 0      Finland  7.741
# 1      Denmark  7.583
# 2      Iceland  7.525

# %%
# Sort the filtered dataset by GDP per Capita in descending order
sorted_high_score_df = high_score_df.sort_values(by='Log GDP per capita', ascending=False)
print("\nTop 10 countries sorted by GDP per Capita:")
sorted_high_score_df.head(10)
# Out:
# Top 10 countries sorted by GDP per Capita:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 0      Finland  7.741               1.844           1.572
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# 0                    0.695                         0.859       0.142
#
#    Perceptions of corruption  Dystopia + residual
# 1                      0.548                1.881
# 2                      0.182                2.050
# 0                      0.546                2.082

# %% [markdown]
# • Adding New Columns:
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
# Medium − (4 ≤ Score ≤ 6)
# High − (Score > 6)

# %%
# Categorize countries based on Score
conditions = [
    (df['score'] < 4),
    (df['score'] >= 4) & (df['score'] <= 6),
    (df['score'] > 6)
]

categories = ['Low', 'Medium', 'High']
df['Happiness Category'] = np.select(conditions, categories)

print("\nDataset with Happiness Category:")
df[['Country name', 'score', 'Happiness Category']].head(143)
# Out:
# Dataset with Happiness Category:
#          Country name  score Happiness Category
# 0             Finland  7.741               High
# 1             Denmark  7.583               High
# 2             Iceland  7.525               High
# 3              Sweden  7.344               High
# 4              Israel  7.341               High
# ..                ...    ...                ...
# 138  Congo (Kinshasa)  3.295                Low
# 139      Sierra Leone  3.245                Low
# 140           Lesotho  3.186                Low
# 141           Lebanon  2.707                Low
# 142       Afghanistan  1.721                Low
#
# [143 rows x 3 columns]

# %% [markdown]
# 2. Data Visualizations:
#
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.
#
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.
#
# • Plot a histogram for the Score column to show its distribution and also interpret.
#
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
#Bar Plot: Top 10 Happiest Countries
top_10_happiest = df.nlargest(10, 'score')

plt.figure(figsize=(10, 6))
sns.barplot(x='score', y='Country name', data=top_10_happiest, color='grey')
plt.title("Top 10 Happiest Countries by Score")
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.show()

# %%
#Line Plot: Top 10 Unhappiest Countries
top_10_unhappiest = df.nsmallest(10, 'score')

plt.figure(figsize=(10, 6))
sns.lineplot(x='score', y='Country name', data=top_10_unhappiest, marker='o')
plt.title("Top 10 Unhappiest Countries by Score")
plt.xlabel("Happiness Score")
plt.ylabel("Country")
plt.show()

# %%
#Histogram of Happiness Scores
plt.figure(figsize=(8, 5))
sns.histplot(df['score'], bins=20, kde=True, color='blue')
plt.title("Distribution of Happiness Scores")
plt.xlabel("Happiness Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The given histogram shows the frequency of happiness scores and a smooth trend line to visualize the data distribution.

# %%
#Scatter Plot: GDP per Capita vs Happiness Score
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=df, hue='Happiness Category', palette='colorblind')
plt.title("GDP per Capita vs Happiness Score")
plt.xlabel("GDP per Capita")
plt.ylabel("Happiness Score")
plt.legend(title="Happiness Category")
plt.show()

# %% [markdown]
# The above  scatter plot visualizes how GDP per Capita relates to Happiness Score, with points categorized by happiness levels using colors. It displays insight into whether wealth influences happiness and how categories distribute in this relationship.

# %% [markdown]
# # 3.2 Problem - 2 - Some Advance Data Exploration Task:
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:
# Steps:
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
# "Maldives", "Nepal", "Pakistan", "Srilanka"]
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
#Create a subset of data for South Asian countries.
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
                          "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

# %%
# Filter South Asian countries
south_asia_df = df[df['Country name'].isin(south_asian_countries)].copy()

# %%
south_asia_df.to_csv('south_asia_data.csv', index=False)

# %%
south_asia_df.head(143)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# Task - 2 - Composite Score Ranking:
# Tasks:
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
# + 0.30 × Healthy Life Expectancy
# 2. Rank the South Asian countries based on the Composite Score in descending order.
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
# Calculate the Composite Score for South Asian countries
south_asia_df['Composite Score'] = (
    0.40 * south_asia_df['Log GDP per capita'] +
    0.30 * south_asia_df['Social support'] +
    0.30 * south_asia_df['Healthy life expectancy']
)

# %%
# Rank the countries based on Composite Score
south_asia_df = south_asia_df.sort_values(by='Composite Score', ascending=False)
south_asia_df['Rank'] = range(1, len(south_asia_df) + 1)

# %%
# Displaying the South Asian countries ranked by Composite Score for review
south_asia_ranked = south_asia_df[['Country name', 'Composite Score', 'Rank']]
south_asia_ranked
# Out:
#     Country name  Composite Score  Rank
# 127    Sri Lanka           1.0739     1
# 92         Nepal           0.8159     2
# 125        India           0.7874     3
# 107     Pakistan           0.7039     4
# 128   Bangladesh           0.6774     5
# 142  Afghanistan           0.3238     6

# %%
#3: Visualize the top 5 South Asian countries using a horizontal bar chart
top_5_south_asian = south_asia_df.head(5)

plt.figure(figsize=(10, 6))
sns.barplot(
    x='Composite Score',
    y='Country name',
    data=top_5_south_asian
)
plt.title("Top 5 South Asian Countries by Composite Score")
plt.xlabel("Composite Score")
plt.ylabel("Country")
plt.show()

# %%
# 4: Compare rankings based on Composite Score and Original Score
comparison = south_asia_df[['Country name', 'Composite Score', 'Rank', 'score']].copy()
comparison['Original Rank'] = comparison['score'].rank(ascending=False)
comparison = comparison.sort_values(by='Rank')

# Visualization: Composite Score Rank vs Original Score Rank
plt.figure(figsize=(10, 6))
sns.lineplot(data=comparison, x='Rank', y='score', label='Original Score')
sns.lineplot(data=comparison, x='Rank', y='Composite Score', label='Composite Score', marker='o')
plt.title("Comparison of Rankings: Composite Score vs Original Score")
plt.xlabel("Rank (Composite Score)")
plt.ylabel("Score")
plt.legend(title="Ranking Basis")
plt.show()

# %% [markdown]
# While the rankings created using the Composite Score and the original Happiness Score are largely similar, there are some noticable differences. This similarity suggests that GDP per capita, social support, and healthy life expectancy are major factors influencing a country's happiness. However, the Composite Score doesn't include all factors that contribute to happiness, such as freedom and generosity, which explains the observed discrepancies. The visualization helps to pinpoint where these ranking differences occur."

# %% [markdown]
# # Task - 3 - Outlier Detection:
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
# Calculate quantiles and IQR for Score and GDP per capita
Q1_score = south_asia_df['score'].quantile(0.25)
Q3_score = south_asia_df['score'].quantile(0.75)
IQR_score = Q3_score - Q1_score

Q1_gdp = south_asia_df['Log GDP per capita'].quantile(0.25)
Q3_gdp = south_asia_df['Log GDP per capita'].quantile(0.75)
IQR_gdp = Q3_gdp - Q1_gdp

# %%
# Define upper and lower bounds for outliers
upper_bound_score = Q3_score + 1.5 * IQR_score
lower_bound_score = Q1_score - 1.5 * IQR_score

upper_bound_gdp = Q3_gdp + 1.5 * IQR_gdp
lower_bound_gdp = Q1_gdp - 1.5 * IQR_gdp

# %%
# Identify Outliers
score_outliers = south_asia_df[
    (south_asia_df['score'] < lower_bound_score) | (south_asia_df['score'] > upper_bound_score)
]
gdp_outliers = south_asia_df[
    (south_asia_df['Log GDP per capita'] < lower_bound_gdp) | (south_asia_df['Log GDP per capita'] > upper_bound_gdp)
]

# %%
# Combine Outliers
outliers = pd.concat([score_outliers, gdp_outliers]).drop_duplicates()

outliers
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 142  Afghanistan  1.721               0.628             0.0
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 142                    0.242                           0.0       0.091
#
#      Perceptions of corruption  Dystopia + residual Happiness Category  \
# 142                      0.088                0.672                Low
#
#      Composite Score  Rank
# 142           0.3238     6

# %%
# 3: Scatter Plot Highlighting Outliers
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asia_df, color='blue', label='Not Outlier')
sns.scatterplot(x='Log GDP per capita', y='score', data=outliers, color='red', label='Outliers')

plt.title("Scatter Plot of GDP per Capita vs Score (Outliers Highlighted)")
plt.xlabel("GDP per Capita")
plt.ylabel("Happiness Score")
plt.legend(title="Outlier", labels=['Not Outlier', 'Outlier'])
plt.show()

# %%
outlier_summary = outliers[['Country name', 'Log GDP per capita', 'score']]
outlier_summary
# Out:
#     Country name  Log GDP per capita  score
# 142  Afghanistan               0.628  1.721

# %% [markdown]
# Q4. Discuss the characteristics of these outliers and their potential impact on regional averages.
#
# Ans : In South Asia, outlier countries such as Afghanistan tend to have significantly lower GDP per capita and happiness scores due to various economic and social difficulties. Likewise, countries with exceptionally high GDP or happiness scores can inflate the regional averages. The presence of these outliers can distort the overall perception of happiness in the region, making it appear more unevenly distributed than it actually is.

# %% [markdown]
# # Task - 4 - Exploring Trends Across Metrics:
# Tasks:
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.
# 2. Create scatter plots with trendlines for these metrics against the Score.
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
# Choose two metrics to analyze
correlation_freedom = south_asia_df['Freedom to make life choices'].corr(south_asia_df['score'], method='pearson')
correlation_generosity = south_asia_df['Generosity'].corr(south_asia_df['score'], method='pearson')

print(f"Correlation between Freedom to Make Life Choices and Score: {correlation_freedom:.2f}")
print(f"Correlation between Generosity and Score: {correlation_generosity:.2f}")
# Out:
# Correlation between Freedom to Make Life Choices and Score: 0.80
# Correlation between Generosity and Score: 0.87

# %%
# Create scatter plots with trendlines
# Scatter plot for Freedom to Make Life Choices vs Score
plt.figure(figsize=(12, 6))
sns.regplot(x='Freedom to make life choices', y='score', data=south_asia_df, color='blue', line_kws={'color': 'red'})
plt.title("Freedom to Make Life Choices vs Happiness Score")
plt.xlabel("Freedom to Make Life Choices")
plt.ylabel("Happiness Score")
plt.show()

# %%
# Scatter plot for Generosity vs Score
plt.figure(figsize=(12, 6))
sns.regplot(x='Generosity', y='score', data=south_asia_df, color='green', line_kws={'color': 'red'})
plt.title("Generosity vs Happiness Score")
plt.xlabel("Generosity")
plt.ylabel("Happiness Score")
plt.show()

# %% [markdown]
# **Strongest Relationship**
#
# -The metric "Freedom to Make Life Choices" displays the strongest interrelation with the Happiness Score.
#
# **Reason:**
#
# -A higher degree of freedom likely reflects better governance, more autonomy, and improved quality of life, which probably contributes to happiness.
#
# -This strong positive relationship is evident in the scatter plot, where the points closely follow the trendline, indicating a linear relationship.

# %% [markdown]
# **Weakest Relationship**
#
# -The metric "Generosity" showed the weakest correlation with the Happiness Score.
#
# **Reason:**
#
# -Generosity may have a limited or indirect influence on happiness in South Asia, possibly overshadowed by more critical factors like economic stability or social support.
#
# -The scatter plot shows a weaker trend, with points scattered farther from the regression line, indicating a less consistent relationship.

# %% [markdown]
# **CONCLUSION:**
#
# Freedom to Make Life Choices has the strongest positive relationship with happiness in south asia as it significantly improves quality of life. However,Generosity shows the weakest relationship indicating it has a less direct impact on happiness in the region. Prioritizing freedom can have a greater effect on improving overall well being.

# %% [markdown]
# # Task - 5 - Gap Analysis:
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
# Step 1: Add a new column for GDP-Score Gap
south_asia_df['GDP-Score Gap'] = south_asia_df['Log GDP per capita'] - south_asia_df['score']
south_asia_df['GDP-Score Gap']
# Out:
# 127   -2.537
# 92    -4.193
# 125   -2.888
# 107   -3.588
# 128   -2.764
# 142   -1.093
# Name: GDP-Score Gap, dtype: float64

# %%
# Step 2: Rank countries by GDP-Score Gap
ascending_gap = south_asia_df.sort_values(by='GDP-Score Gap', ascending=True)
descending_gap = south_asia_df.sort_values(by='GDP-Score Gap', ascending=False)

# %%
# Step 3: Visualize the top 3 countries with the largest positive and negative gaps
top_3_positive_gap = descending_gap.head(3)
top_3_negative_gap = ascending_gap.head(3)

# %%
# Bar chart for positive gaps
plt.barh(top_3_positive_gap['Country name'], top_3_positive_gap['GDP-Score Gap'], color='grey', label='Positive Gap')
# Bar chart for negative gaps
plt.barh(top_3_negative_gap['Country name'], top_3_negative_gap['GDP-Score Gap'], color='black', label='Negative Gap')

plt.title("Top 3 Countries with Largest GDP-Score Gaps")
plt.xlabel("GDP-Score Gap")
plt.ylabel("Country")
plt.legend()
plt.show()

# %% [markdown]
# Q4.
# GDP-Score gaps highlight that wealth alone doesn't ensure happiness. Positive gaps (high GDP, low happiness) result from inequality or poor governance, while negative gaps (low GDP, high happiness) comes from strong social support and cultural resilience. South Asian countries should focus on reducing inequality, improving governance, and preserving social relation to bridge these gaps and enhance overall well-being.

# %% [markdown]
# # 3.3 Problem - 3 - Comparative Analysis:
# Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:

# %% [markdown]
# Tasks:
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries.
#
# For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
# "United Arab Emirates", "Yemen"]
# Complete the following task:
# 1. Descriptive Statistics:
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
# • Which region has higher happiness Scores on average?
# 2. Top and Bottom Performers:
# • Identify the top 3 and bottom 3 countries in each region based on the score.
# • Plot bar charts comparing these charts.
# 3. Metric Comparisons:
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.
# • Which metrics show the largest disparity between the two regions?
# 4. Happiness Disparity:
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
# • Which region has greater variability in happiness?
# 5. Correlation Analysis:
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
# • Create scatter plots to visualize and interpret the relationships.
# 6. Outlier Detection:
# • Identify outlier countries in both regions based on Score and GDP per Capita.
# • Plot these outliers and discuss their implications.
# 7. Visualization:
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
# Step 1: Dataset Preparation
middle_eastern_countries = ["Bahrain", "Egypt", "Iran", "Iraq", "Israel",
                            "Jordan", "Kuwait", "Lebanon", "Oman",
                            "Qatar", "Saudi Arabia", "Syria", "Turkey", "UAE", "Yemen"]

# Filter datasets for Middle East and South Asia
middle_east_df = df[df['Country name'].isin(middle_eastern_countries)].copy()

# %%
#2
# Calculate mean and standard deviation of Score
south_asia_mean = south_asia_df['score'].mean()
south_asia_std = south_asia_df['score'].std()
middle_east_mean = middle_east_df['score'].mean()
middle_east_std = middle_east_df['score'].std()

print(f"South Asia: Mean Score = {south_asia_mean:.2f}, Standard Deviation = {south_asia_std:.2f}")
print(f"Middle East: Mean Score = {middle_east_mean:.2f}, Standard Deviation = {middle_east_std:.2f}")

# Compare average happiness scores
if south_asia_mean > middle_east_mean:
    print("\nSouth Asia has a higher average happiness score.")
else:
    print("\nMiddle East has a higher average happiness score.")
# Out:
# South Asia: Mean Score = 3.90, Standard Deviation = 1.18
# Middle East: Mean Score = 5.14, Standard Deviation = 1.55
#
# Middle East has a higher average happiness score.

# %%
# South Asia
top_3_south_asia = south_asia_df.nlargest(3, 'score')  # Top 3 by score
bottom_3_south_asia = south_asia_df.nsmallest(3, 'score')  # Bottom 3 by score

# Middle East
top_3_middle_east = middle_east_df.nlargest(3, 'score')  # Top 3 by score
bottom_3_middle_east = middle_east_df.nsmallest(3, 'score')  # Bottom 3 by score

# Create subplots for side-by-side comparison
# South Asia: Top 3 and Bottom 3 Countries by Score
plt.figure(figsize=(14, 6))

# South Asia Plot
plt.subplot(1, 2, 1)  # 1 row, 2 columns, 1st plot
sns.barplot(x='score', y='Country name', data=top_3_south_asia, color='skyblue', label='Top 3')
sns.barplot(x='score', y='Country name', data=bottom_3_south_asia, color='salmon', label='Bottom 3')
plt.title('South Asia: Top and Bottom 3 Countries by Score')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.legend()

# Middle East: Top 3 and Bottom 3 Countries by Score
plt.subplot(1, 2, 2)  # 1 row, 2 columns, 2nd plot
sns.barplot(x='score', y='Country name', data=top_3_middle_east, color='skyblue', label='Top 3')
sns.barplot(x='score', y='Country name', data=bottom_3_middle_east, color='salmon', label='Bottom 3')
plt.title('Middle East: Top and Bottom 3 Countries by Score')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.legend()

# Adjust layout and display the plots
plt.tight_layout()
plt.show()

# %%
# Step 3: Metric Comparisons
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
metric_means = pd.DataFrame({
    "Metric": metrics,
    "South Asia": [south_asia_df[metric].mean() for metric in metrics],
    "Middle East": [middle_east_df[metric].mean() for metric in metrics]
})

# Grouped Bar Chart
metric_means.set_index("Metric").plot(kind="bar", figsize=(10, 6))
plt.title("Comparison of Metrics: South Asia vs Middle East")
plt.ylabel("Average Value")
plt.xticks(rotation=45)
plt.legend(title="Region")
plt.show()

# %%
# Step 4: Happiness Disparity Analysis

# Compute range and coefficient of variation for South Asia
south_asia_range = south_asia_df['score'].max() - south_asia_df['score'].min()
south_asia_cv = south_asia_df['score'].std() / south_asia_df['score'].mean()

# Compute range and coefficient of variation for Middle East
middle_east_range = middle_east_df['score'].max() - middle_east_df['score'].min()
middle_east_cv = middle_east_df['score'].std() / middle_east_df['score'].mean()

# Display results
happiness_disparity = pd.DataFrame({
    "Region": ["South Asia", "Middle East"],
    "Range": [south_asia_range, middle_east_range],
    "Coefficient of Variation": [south_asia_cv, middle_east_cv]
})

# Print results for both regions
print("Happiness Disparity Analysis:")
print(happiness_disparity)

# Determine which region has greater variability
if south_asia_cv > middle_east_cv:
    print("\nSouth Asia has greater variability in happiness scores.")
else:
    print("\nMiddle East has greater variability in happiness scores.")
# Out:
# Happiness Disparity Analysis:
#         Region  Range  Coefficient of Variation
# 0   South Asia  3.437                  0.302148
# 1  Middle East  4.634                  0.301829
#
# South Asia has greater variability in happiness scores.

# %%
#5
# Metrics for correlation
correlation_metrics = ['Freedom to make life choices', 'Generosity']

# Create a figure with subplots for side-by-side visualizations
plt.figure(figsize=(14, 10))

# South Asia: Freedom to Make Life Choices vs Score
plt.subplot(2, 2, 1)
sns.regplot(x='Freedom to make life choices', y='score', data=south_asia_df, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title("South Asia: Freedom to Make Life Choices vs. Score")
plt.xlabel("Freedom to Make Life Choices")
plt.ylabel("Happiness Score")

# Middle East: Freedom to Make Life Choices vs Score
plt.subplot(2, 2, 2)
sns.regplot(x='Freedom to make life choices', y='score', data=middle_east_df, scatter_kws={'color': 'orange'}, line_kws={'color': 'red'})
plt.title("Middle East: Freedom to Make Life Choices vs. Score")
plt.xlabel("Freedom to Make Life Choices")
plt.ylabel("Happiness Score")

# South Asia: Generosity vs Score
plt.subplot(2, 2, 3)
sns.regplot(x='Generosity', y='score', data=south_asia_df, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title("South Asia: Generosity vs. Score")
plt.xlabel("Generosity")
plt.ylabel("Happiness Score")

# Middle East: Generosity vs Score
plt.subplot(2, 2, 4)
sns.regplot(x='Generosity', y='score', data=middle_east_df, scatter_kws={'color': 'orange'}, line_kws={'color': 'red'})
plt.title("Middle East: Generosity vs. Score")
plt.xlabel("Generosity")
plt.ylabel("Happiness Score")

plt.tight_layout()
plt.show()

# Calculate and Print Correlations for Both Regions
print("\nCorrelation Analysis:")
print("South Asia:")
print(f"Freedom to Make Life Choices Correlation: {south_asia_df['Freedom to make life choices'].corr(south_asia_df['score']):.2f}")
print(f"Generosity Correlation: {south_asia_df['Generosity'].corr(south_asia_df['score']):.2f}")

print("\nMiddle East:")
print(f"Freedom to Make Life Choices Correlation: {middle_east_df['Freedom to make life choices'].corr(middle_east_df['score']):.2f}")
print(f"Generosity Correlation: {middle_east_df['Generosity'].corr(middle_east_df['score']):.2f}")
# Out:
# Correlation Analysis:
# South Asia:
# Freedom to Make Life Choices Correlation: 0.80
# Generosity Correlation: 0.87
#
# Middle East:
# Freedom to Make Life Choices Correlation: 0.83
# Generosity Correlation: 0.61

# %%
# Outlier Detection Without Functions

# Calculate IQR and Outliers for South Asia
Q1_score_sa = south_asia_df['score'].quantile(0.25)
Q3_score_sa = south_asia_df['score'].quantile(0.75)
IQR_score_sa = Q3_score_sa - Q1_score_sa
score_lower_sa = Q1_score_sa - 1.5 * IQR_score_sa
score_upper_sa = Q3_score_sa + 1.5 * IQR_score_sa

Q1_gdp_sa = south_asia_df['Log GDP per capita'].quantile(0.25)
Q3_gdp_sa = south_asia_df['Log GDP per capita'].quantile(0.75)
IQR_gdp_sa = Q3_gdp_sa - Q1_gdp_sa
gdp_lower_sa = Q1_gdp_sa - 1.5 * IQR_gdp_sa
gdp_upper_sa = Q3_gdp_sa + 1.5 * IQR_gdp_sa

score_outliers_sa = south_asia_df[(south_asia_df['score'] < score_lower_sa) | (south_asia_df['score'] > score_upper_sa)]
gdp_outliers_sa = south_asia_df[(south_asia_df['Log GDP per capita'] < gdp_lower_sa) | (south_asia_df['Log GDP per capita'] > gdp_upper_sa)]
all_outliers_sa = pd.concat([score_outliers_sa, gdp_outliers_sa]).drop_duplicates()

# Calculate IQR and Outliers for Middle East
Q1_score_me = middle_east_df['score'].quantile(0.25)
Q3_score_me = middle_east_df['score'].quantile(0.75)
IQR_score_me = Q3_score_me - Q1_score_me
score_lower_me = Q1_score_me - 1.5 * IQR_score_me
score_upper_me = Q3_score_me + 1.5 * IQR_score_me

Q1_gdp_me = middle_east_df['Log GDP per capita'].quantile(0.25)
Q3_gdp_me = middle_east_df['Log GDP per capita'].quantile(0.75)
IQR_gdp_me = Q3_gdp_me - Q1_gdp_me
gdp_lower_me = Q1_gdp_me - 1.5 * IQR_gdp_me
gdp_upper_me = Q3_gdp_me + 1.5 * IQR_gdp_me

score_outliers_me = middle_east_df[(middle_east_df['score'] < score_lower_me) | (middle_east_df['score'] > score_upper_me)]
gdp_outliers_me = middle_east_df[(middle_east_df['Log GDP per capita'] < gdp_lower_me) | (middle_east_df['Log GDP per capita'] > gdp_upper_me)]
all_outliers_me = pd.concat([score_outliers_me, gdp_outliers_me]).drop_duplicates()

# Scatter plots for visualization
plt.figure(figsize=(12, 6))

# South Asia
plt.subplot(1, 2, 1)
sns.scatterplot(x='Log GDP per capita', y='score', data=south_asia_df, color='blue', label='Normal Data')
sns.scatterplot(x='Log GDP per capita', y='score', data=all_outliers_sa, color='red', label='Outliers')
plt.title("South Asia: Outliers in GDP per capita and score")
plt.xlabel("Log GDP per Capita")
plt.ylabel("Happiness Score")
plt.legend()

# Middle East
plt.subplot(1, 2, 2)
sns.scatterplot(x='Log GDP per capita', y='score', data=middle_east_df, color='orange', label='Normal Data')
sns.scatterplot(x='Log GDP per capita', y='score', data=all_outliers_me, color='red', label='Outliers')
plt.title("Middle East: Outliers in GDP per capita and score")
plt.xlabel("Log GDP per Capita")
plt.ylabel("Happiness Score")
plt.legend()

plt.tight_layout()
plt.show()

# Display Outliers
print("\nOutliers Detected in South Asia:")
print(all_outliers_sa[['Country name', 'Log GDP per capita', 'score']])

print("\nOutliers Detected in Middle East:")
print(all_outliers_me[['Country name', 'Log GDP per capita', 'score']])

print("\nImplications:")
print("Outliers highlight countries with extreme scores or GDP values. In South Asia, these may indicate socio-economic disparities, while in the Middle East, they could reflect resource-rich nations or conflict-driven struggles.")
# Out:
# Outliers Detected in South Asia:
#     Country name  Log GDP per capita  score
# 142  Afghanistan               0.628  1.721
#
# Outliers Detected in Middle East:
# Empty DataFrame
# Columns: [Country name, Log GDP per capita, score]
# Index: []
#
# Implications:
# Outliers highlight countries with extreme scores or GDP values. In South Asia, these may indicate socio-economic disparities, while in the Middle East, they could reflect resource-rich nations or conflict-driven struggles.

# %%
# Step 7: Visualization - Boxplots

# Create boxplots for Score in South Asia and Middle East
plt.figure(figsize=(10, 6))
sns.boxplot(x='Region', y='score', data=pd.concat([
    south_asia_df.assign(Region='South Asia'),
    middle_east_df.assign(Region='Middle East')
]))
plt.title("Distribution of Happiness Scores: South Asia vs Middle East")
plt.xlabel("Region")
plt.ylabel("Happiness Score")
plt.show()

# %% [markdown]
# Interpretation of Boxplots:
# ----------------------------
# 1. Distribution Shapes:
# - South Asia: The Happiness score of South Asia are slightly goes downward, while scores in the Middle East are more evenly distributed.
#
# - Middle East: The boxplot for the Middle East appears to be more symmetric, with a relatively even distribution of scores around the median.
#
# 2. Medians:
# - South Asia: The median happiness score for South Asia is slightly lower than that of the Middle East, as indicated by the position of the horizontal line within the box.
# - Middle East: The median happiness score for the Middle East is slightly higher, suggesting a generally higher level of happiness in the region.
#
# 3. Outliers:
# - South Asia: There are potential outliers on the lower end of the distribution for South Asia, represented by the individual points below the lower whisker.
# - Middle East: There are potential outliers on both ends of the distribution for the Middle East, indicating a wider range of happiness scores in the region.
#
# Overall, the boxplots suggest that while there are some differences in the distribution of happiness scores between South Asia and the Middle East, the median scores are relatively similar. However, the presence of outliers and differences in distribution shapes indicate variations in happiness levels within each region.
