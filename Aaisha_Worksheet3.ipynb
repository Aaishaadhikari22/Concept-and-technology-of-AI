# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Datasets/Titanic-Dataset (1).csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
fare_df = df[["Fare"]]
fare_df.head()
# Out:
#       Fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %%
class_age = df[["Pclass","Age"]]
class_age.head()
# Out:
#    Pclass   Age
# 0       3  22.0
# 1       1  38.0
# 2       3  26.0
# 3       1  35.0
# 4       3  35.0

# %%
survived_gender = df[["Survived", "Sex"]]
survived_gender.head()
# Out:
#    Survived     Sex
# 0         0    male
# 1         1  female
# 2         1  female
# 3         1  female
# 4         0    male

# %%
fare_gt_100 = df.loc[(df["Fare"] > 100)]
fare_gt_100
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 299          300         1       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 311          312         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 341          342         1       1
# 373          374         0       1
# 377          378         0       1
# 380          381         1       1
# ...

# %%
first_class = df.loc[(df["Pclass"] == 1)]
first_class
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
female_under_18 = df[(df["Age"] > 18) & (df["Sex"] == "female")]
female_under_18
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 879          880         1       1
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
embarked_c_or_s = df[(df["Embarked"].isin(["C", "S"]))]
embarked_c_or_s
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
first_second_class = df[(df["Pclass"].isin([1, 2]))]
first_second_class
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# ..           ...       ...     ...
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Exploratory Data Analysis Practice Exercise**

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["fare_per_year"] = df["Fare"] / df["Age"]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
high_fare_age = df.loc[(df["fare_per_year"] > 5)]
high_fare_age
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 16            17         0       3
# 27            28         0       1
# 31            32         1       1
# 43            44         1       2
# ..           ...       ...     ...
# 813          814         0       3
# 824          825         0       3
# 827          828         1       2
# 831          832         1       2
# 850          851         0       3
#
#                                                Name     Sex    Age  SibSp  \
# 7                    Palsson, Master. Gosta Leonard    male   2.00      3
# 16                             Rice, Master. Eugene    male   2.00      4
# 27                   Fortune, Mr. Charles Alexander    male  19.00      3
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female  28.00      1
# 43         Laroche, Miss. Simonne Marie Anne Andree  female   3.00      1
# ..                                              ...     ...    ...    ...
# ...

# %%
high_fare_age = df.sort_values(["fare_per_year"], ascending=[False])
high_fare_age
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 297          298         0       1     Allison, Miss. Helen Loraine  female
# 386          387         0       3  Goodwin, Master. Sidney Leonard    male
# 164          165         0       3     Panula, Master. Eino Viljami    male
# 183          184         1       2        Becker, Master. Richard F    male
# ..           ...       ...     ...                              ...     ...
# 179          180         0       3              Leonard, Mr. Lionel    male
# 822          823         0       1  Reuchlin, Jonkheer. John George    male
# 263          264         0       1            Harrison, Mr. William    male
# 815          816         0       1                 Fry, Mr. Richard    male
# 806          807         0       1           Andrews, Mr. Thomas Jr    male
#
# ...

# %%
df["fare_per_class"] = df["Fare"] / df["Pclass"]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
adult_males = df.loc[(df["Age"] > 18)]
adult_males
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
adult_males_srt = df.sort_values(["fare_per_class"], ascending=[False])
adult_males_srt
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 438          439         0       1                   Fortune, Mr. Mark
# ..           ...       ...     ...                                 ...
# 271          272         1       3        Tornquist, Mr. William Henry
# 263          264         0       1               Harrison, Mr. William
# 597          598         0       3                 Johnson, Mr. Alfred
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# ...

# %%
result = adult_males_srt[["Name", "Age", "fare_per_class"]]
result
# Out:
#                                    Name   Age  fare_per_class
# 258                    Ward, Miss. Anna  35.0        512.3292
# 679  Cardeza, Mr. Thomas Drake Martinez  36.0        512.3292
# 737              Lesurer, Mr. Gustave J  35.0        512.3292
# 88           Fortune, Miss. Mabel Helen  23.0        263.0000
# 438                   Fortune, Mr. Mark  64.0        263.0000
# ..                                  ...   ...             ...
# 271        Tornquist, Mr. William Henry  25.0          0.0000
# 263               Harrison, Mr. William  40.0          0.0000
# 597                 Johnson, Mr. Alfred  49.0          0.0000
# 633       Parr, Mr. William Henry Marsh  28.0          0.0000
# 674          Watson, Mr. Ennis Hastings  28.0          0.0000
#
# [891 rows x 3 columns]

# %% [markdown]
# **3.3 Exploratory Data Analysis with Group-by Method Practice Exercise:**

# %%
total_fare = df["Fare"].sum()
total_fare
# Out:
# 28693.9493

# %%
first_class_passenger = df.loc[(df["Pclass"] == 1)]
first_class_passenger_total_fare = first_class_passenger["Fare"].sum()
first_class_passenger_total_fare
# Out:
# 18177.4125

# %%
second_class_passenger = df.loc[(df["Pclass"] == 2)]
second_class_passenger_total_fare = second_class_passenger["Fare"].sum()
second_class_passenger_total_fare
# Out:
# 3801.8417

# %%
third_class_passenger = df.loc[(df["Pclass"] == 3)]
third_class_passenger_total_fare = third_class_passenger["Fare"].sum()
third_class_passenger_total_fare
# Out:
# 6714.6951

# %%
total_fare_list = []
total_fare_list.append(first_class_passenger_total_fare)
total_fare_list.append(second_class_passenger_total_fare)
total_fare_list.append(third_class_passenger_total_fare)
total_fare_list
# Out:
# [18177.4125, 3801.8417, 6714.6951]

# %%
fare_revenue_class = []
for i in total_fare_list:
    fare_revenue_class.append(i/total_fare)
fare_revenue_class
# Out:
# [0.6334928771899656, 0.1324962855496507, 0.23401083726038366]

# %% [markdown]
# **What percent of the total number of passengers on the Titanic belonged to each age group (e.g., child, adult, senior)?**

# %%
def categorize_age(age):
    if age < 18:
        return "child"
    elif 18 <= age < 65:
        return "adult"
    else:
        return "senior"

df["age_group"] = df["Age"].apply(categorize_age)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
total_number_passenger = df["PassengerId"].count()
total_number_passenger
# Out:
# 891

# %%
child_passenger = df["age_group"].value_counts()
child_passenger
# Out:
# age_group
# adult     590
# senior    188
# child     113
# Name: count, dtype: int64

# %%
proportion_age_group = df["age_group"].value_counts() / total_number_passenger
proportion_age_group
# Out:
# age_group
# adult     0.662177
# senior    0.210999
# child     0.126824
# Name: count, dtype: float64

# %%
proportion_age_group_percentage = ((df["age_group"].value_counts() / total_number_passenger) * 100).round(2)
proportion_age_group_percentage
# Out:
# age_group
# adult     66.22
# senior    21.10
# child     12.68
# Name: count, dtype: float64
